# %% [markdown]
# # Giga coders
# ## Machine learning

# %% [markdown]
# **Machine learning**
#
#
# *   Aprendizaje supervisado
# *   Aprendizaje no superviado
# *   Aprendizaje por refuerzo

# %% [markdown]
# **Aprendizaje supervisado**
#
#
# *   Problemas de clasificación
# *   Problemas de regresión

# %% [markdown]
# ![alt text](https://miro.medium.com/max/1838/1*ASYpFfDh7XnreU-ygqXonw.png)

# %% [markdown]
# ## **Problemas de clasificación**
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Perceptron_example.svg/500px-Perceptron_example.svg.png)

# %% [markdown]
# ## **Perceptron / Single-layer perceptron**
#
# Neurona:
# ![alt text](https://comofuncionaque.com/wp-content/uploads/2015/09/estructura-neuronal1-1024x550.png)
#
# El perceptrón, creado por Frank Rosenblatt en 1958.
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Perceptr%C3%B3n_5_unidades.svg/1920px-Perceptr%C3%B3n_5_unidades.svg.png)
#
# En 1969, Minsky propuso una versión mejorada del modelo conocido como perceptrón.
#
# ![alt text](https://miro.medium.com/max/645/1*-JtN9TWuoZMz7z9QKbT85A.png)
#
# Fuentes de consulta:
#
# *   https://www.mathworks.com/help/deeplearning/ug/perceptron-neural-networks.html;jsessionid=41e06bf62a0839c6795a2f682de2

# %% [markdown]
# ## **Weights and bias**
#
# ![alt text](https://www.mathworks.com/help/deeplearning/ug/percept_percla.gif)
# ![alt text](http://1.bp.blogspot.com/-7GA3N5-Q8UY/UCnkSRpd8EI/AAAAAAAAAdM/bjNoVxvIeKw/s1600/ajuste+de+pesos.png)

# %% [markdown]
# ## Hiperparámetros
#
#
# *  **Learning rate**
#
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRcxcgZqHAhi-2bnoQja5HMzsh_e_HVnO5Ig-LJpIsoKt52yRSy)

# %% [markdown]
# ## Active functions
#
#
#
# *   Binary step function (hardlim)
# *   Linear activation function
# *   Non-linear activation function
#
# ![alt text](http://baydeltaoffice.water.ca.gov/modeling/deltamodeling/delta/reports/annrpt/1995/fig7_2.gif)
#
#
# **Hardlim**
#
# ![alt text](https://edoras.sdsu.edu/doc/matlab/toolbox/nnet/hardlim.gif)

# %% [markdown]
# ## Hiperplano
#
# En un espacio unidimensional (como una recta), un hiperplano es un punto: divide una línea en dos líneas. En un espacio bidimensional (como el plano xy), un hiperplano es una recta: divide el plano en dos mitades. En un espacio tridimensional, un hiperplano es un plano corriente: divide el espacio en dos mitades.
#
# ![alt text](data:image/png;base64,...)

# %% [markdown]
# ## Código Perceptrón Hardlim

# %%
import tensorflow as tf
import cv2
import numpy as np
from numpy import array, dot, random
import pandas
import matplotlib.pyplot as plt
from random import choice

print("alles ist gut")
# Out:
# alles ist gut

# %% [markdown]
# ## Perceptrón compuerta OR
#
# ![alt text](https://www.monografias.com/trabajos101/practicas-electronica-digital-ii/image003.png)

# %%
unit_step = lambda x: 0 if x < 0 else 1

training_data = [
    (array([0,0,1]), 0),
    (array([0,1,1]), 1),
    (array([1,0,1]), 1),
    (array([1,1,1]), 1),
]

w = random.rand(3)
errors = []
eta = 0.2
n = 100

for i in range(n):
    x, expected = choice(training_data)
    result = dot(w, x)
    error = expected - unit_step(result)
    errors.append(error)
    w += eta * error * x

for x, _ in training_data:
    result = dot(x, w)
    print("{}: {} -> {}".format(x[:2], result, unit_step(result)))
# Out:
# [0 0]: -0.14607176189334364 -> 0
# [0 1]: 0.7936939310130136 -> 1
# [1 0]: 0.09717314025933665 -> 1
# [1 1]: 1.036938833165694 -> 1

# %% [markdown]
# ## Ejercicio de clase
#
# https://drive.google.com/file/d/1vBR9FhwsrQdXMDVonZkcQmOvMCKcEsxr/view?usp=sharing

# %%
unit_step = lambda x: 0 if x < 0 else 1

training_data = [
    (array([0,0,1]), 0),
    (array([1,1,1]), 0),
    (array([1,5,1]), 0),
    (array([2,2,1]), 0),
    (array([2,3,1]), 0),
    (array([3,1,1]), 0),
    (array([3,2,1]), 0),
    (array([4,1,1]), 0),
    (array([1,9,1]), 1),
    (array([1,10,1]), 1),
    (array([2,8,1]), 1),
    (array([2,9,1]), 1),
    (array([3,7,1]), 1),
    (array([3,8,1]), 1),
    (array([4,6,1]), 1),
    (array([4,7,1]), 1),
    (array([5,5,1]), 1),
    (array([5,6,1]), 1),
    (array([6,3,1]), 1),
    (array([6,4,1]), 1)
]

w = random.rand(3)
errors = []
eta = 0.2
n = 1000

for i in range(n):
    x, expected = choice(training_data)
    result = dot(w, x)
    error = expected - unit_step(result)
    errors.append(error)
    w += eta * error * x

for x, _ in training_data:
    result = dot(x, w)
    print("{}: {} -> {}".format(x[:2], result, unit_step(result)))
# Out:
# [0 0]: -5.802934962509691 -> 0
# [1 1]: -3.7988227680551945 -> 0
# [1 5]: -0.49011843327987226 -> 0
# [2 2]: -1.7947105736006979 -> 0
# [2 3]: -0.9675344899068667 -> 0
# [3 1]: -1.444950546533863 -> 0
# [3 2]: -0.6177744628400319 -> 0
# [4 1]: -0.26801443577319706 -> 0
# [1 9]: 2.8185859014954504 -> 1
# [ 1 10]: 3.6457619851892806 -> 1
# [2 8]: 3.168345928562286 -> 1
# [2 9]: 3.9955220122561164 -> 1
# [3 7]: 3.518105955629122 -> 1
# [3 8]: 4.345282039322952 -> 1
# [4 6]: 3.8678659826959576 -> 1
# [4 7]: 4.695042066389788 -> 1
# [5 5]: 4.217626009762792 -> 1
# [5 6]: 5.044802093456622 -> 1
# [6 3]: 3.740209953135797 -> 1
# [6 4]: 4.567386036829627 -> 1

# %%
#test: 
print("TEST")
test_data = [
    (array([1,3,1]), 0),
    (array([4,8,1]), 1)
]

correctas=0
for x, r in test_data:
    result = dot(x, w)
    print("{}: {} -> {}".format(x[:2], result, unit_step(result)))
    if unit_step(result) == r:
        correctas = correctas +1

porcentaje = (correctas*100) / len(test_data)
print("Tu modelo tiene un porcentaje de {} '%'  de respuestas correctas.".format(porcentaje))
# Out:
# TEST
# [1 3]: -2.144470600667533 -> 0
# [4 8]: 5.522218150083618 -> 1
# Tu modelo tiene un porcentaje de 100.0 '%'  de respuestas correctas.

# %% [markdown]
# ## Actividades para mejorar
#
#
# *   Lectura de http://ciml.info/dl/v0_99/ciml-v0_99-ch04.pdf
# *   Crear un problema de clasificación con diferentes datos que puedan ser separados en dos categorías, y aplicar un single layer perceptron con hardlim como activation function
